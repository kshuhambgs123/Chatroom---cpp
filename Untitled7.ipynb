# %% [markdown]
# <a href="https://colab.research.google.com/github/kshuhambgs123/Chatroom---cpp/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # %matplotlib inline
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Handle table-like data and matrices
import numpy as np
import pandas as pd

# Visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# utils
from matplotlib.pyplot import imread
from skimage.transform import resize
import os
import random

# Configure visualisations
# %matplotlib inline
color = sns.color_palette()
pd.options.mode.chained_assignment = None
pd.options.display.max_columns = 999
mpl.style.use( 'ggplot' )
sns.set_style( 'white' )
pylab.rcParams[ 'figure.figsize' ] = 10,8

# %%
def bar_plot(df, col, text = True, k = None, rot = 0):
    """
    Arguments:
    x : pandas series
    Returns:
    seaborn barplot with text on top
    """
    if k == None:
        x = df[col].value_counts()
    else:
        x = df[col].value_counts()[:k]
    ax= sns.barplot(x.index, x.values, alpha=0.8)
    plt.title("# per class")
    plt.ylabel('# of Occurrences', fontsize=12)
    plt.xlabel(col, fontsize=12)
    #adding the text labels
    if text:
        rects = ax.patches
        labels = x.values
        for rect, label in zip(rects, labels):
            height = rect.get_height()
            ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom')
    plt.xticks(rotation = rot)
    plt.show()

# %%
# set the root path
root_dir = os.path.abspath('.')
# set the data dir
data_dir = '/content/drive/MyDrive/Age-Detection-mod/input'

# %%
train = pd.read_csv(os.path.join(data_dir, 'train.csv'))
test = pd.read_csv(os.path.join(data_dir, 'test.csv'))

# %%
# train.head()
#train.sort_values(["ID"], 
  #                  axis=0,
 #                   ascending=[True], 
  #                  inplace=True)
train.head()
# Out:
#           ID   Class
# 0    377.jpg  MIDDLE
# 1  17814.jpg   YOUNG
# 2  21283.jpg  MIDDLE
# 3  16496.jpg   YOUNG
# 4   4487.jpg  MIDDLE

# %%
print("Train shape :",train.shape)
print("Test shape :",test.shape)
# Out:
# Train shape : (19906, 2)
# Test shape : (6636, 1)

# %%
def show_random_image(df, folder_name):
    i = random.choice(df.index)

    img_name = df.ID[i]
    img = imread(os.path.join(data_dir, folder_name, img_name))

    print('Age : ', train.Class[i])
    plt.imshow(img)

# %%
# show random image 
show_random_image(train, "train")
# Out:
# Age :  MIDDLE

# %%
def resize_img(df, folder_name):
    temp = []
    for index,img_name in enumerate(df.ID):
        if index % 1000 == 0:
            print ('Index :',index)
        img_path = os.path.join(data_dir, folder_name, img_name)
        img = imread(img_path)
        img = resize(img, (32, 32))
        img = img.astype('float32')
        temp.append(img)

    return np.stack(temp)

# %%
# resize all the images 32 x 32 (training set), usually takes ~ 4-5 min (CPU)
train_x = resize_img(train, "train")
# Out:
# Index : 0

# %%
# resize all the images 32 x 32 (testing set)
test_x = resize_img(test, "test")
# Out:
# Index : 0
# Index : 1000
# Index : 2000
# Index : 3000
# Index : 4000
# Index : 5000
# Index : 6000

# %%
# flatten the image array
train_x = train_x / 255
test_x = test_x / 255

# %%
bar_plot(train, "Class")

# %%
import keras
from sklearn.preprocessing import LabelEncoder

lb = LabelEncoder()
train_y = lb.fit_transform(train.Class)
train_y = keras.utils.np_utils.to_categorical(train_y)

# %%
# set up the parameters for neural network
input_num_units = (32, 32, 3)
hidden_num_units = 600
output_num_units = 3
num_filter = 100

epochs = 30
batch_size = 64

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten, InputLayer
from keras.layers import Conv2D, MaxPooling2D, Dropout

# %%
model = Sequential()

## Input Layer
model.add(InputLayer(input_shape=input_num_units))

## Convolutional layer
model.add(Conv2D(num_filter, (3, 3), activation='relu', input_shape=input_num_units))

model.add(MaxPooling2D())

model.add(Dropout(0.25))

model.add(Conv2D(int(num_filter * 0.5), (3, 3), activation='relu', input_shape=(10, 10, 100)))

model.add(MaxPooling2D())

model.add(Dropout(0.25))

model.add(Conv2D(int(num_filter * 0.3), (3, 3), activation='relu', input_shape=(1, 1, 10)))

model.add(Flatten())

model.add(Dense(hidden_num_units, activation='relu'))

model.add(Dropout(0.5))

model.add(Dense(int(hidden_num_units * 0.2), activation='relu'))

model.add(Dense(units=output_num_units, activation='softmax'))

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5f15418b3570> in <cell line: 1>()
# ----> 1 model.summary()
#
# NameError: name 'model' is not defined

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# model.fit(train_x, train_y, batch_size=batch_size,epochs=epochs,verbose=1)

# %%
model.fit(train_x, train_y, batch_size=batch_size,epochs=epochs,verbose=1, validation_split=0.1)
# Out:
# Epoch 1/30
# 280/280 [==============================] - 80s 274ms/step - loss: 0.9615 - accuracy: 0.5421 - val_loss: 0.9488 - val_accuracy: 0.5379
# Epoch 2/30
# 280/280 [==============================] - 83s 296ms/step - loss: 0.9552 - accuracy: 0.5433 - val_loss: 0.9504 - val_accuracy: 0.5379
# Epoch 3/30
# 280/280 [==============================] - 79s 282ms/step - loss: 0.9534 - accuracy: 0.5432 - val_loss: 0.9482 - val_accuracy: 0.5379
# Epoch 4/30
# 280/280 [==============================] - 76s 270ms/step - loss: 0.9555 - accuracy: 0.5433 - val_loss: 0.9500 - val_accuracy: 0.5379
# Epoch 5/30
# 280/280 [==============================] - 79s 281ms/step - loss: 0.9549 - accuracy: 0.5433 - val_loss: 0.9505 - val_accuracy: 0.5379
# Epoch 6/30
# 280/280 [==============================] - 76s 272ms/step - loss: 0.9553 - accuracy: 0.5433 - val_loss: 0.9503 - val_accuracy: 0.5379
# Epoch 7/30
# 280/280 [==============================] - 80s 286ms/step - loss: 0.9549 - accuracy: 0.5433 - val_loss: 0.9485 - val_accuracy: 0.5379
# Epoch 8/30
# 280/280 [==============================] - 77s 275ms/step - loss: 0.9549 - accuracy: 0.5433 - val_loss: 0.9488 - val_accuracy: 0.5379
# Epoch 9/30
# 280/280 [==============================] - 72s 258ms/step - loss: 0.9546 - accuracy: 0.5433 - val_loss: 0.9501 - val_accuracy: 0.5379
# Epoch 10/30
# 280/280 [==============================] - 80s 286ms/step - loss: 0.9547 - accuracy: 0.5433 - val_loss: 0.9481 - val_accuracy: 0.5379
# Epoch 11/30
# 280/280 [==============================] - 75s 268ms/step - loss: 0.9547 - accuracy: 0.5433 - val_loss: 0.9499 - val_accuracy: 0.5379
# Epoch 12/30
# 280/280 [==============================] - 77s 274ms/step - loss: 0.9545 - accuracy: 0.5433 - val_loss: 0.9489 - val_accuracy: 0.5379
# Epoch 13/30
# 280/280 [==============================] - 77s 274ms/step - loss: 0.9543 - accuracy: 0.5433 - val_loss: 0.9483 - val_accuracy: 0.5379
# Epoch 14/30
# 280/280 [==============================] - 79s 284ms/step - loss: 0.9545 - accuracy: 0.5433 - val_loss: 0.9490 - val_accuracy: 0.5379
# Epoch 15/30
# 280/280 [==============================] - 81s 289ms/step - loss: 0.9541 - accuracy: 0.5433 - val_loss: 0.9494 - val_accuracy: 0.5379
# Epoch 16/30
# 280/280 [==============================] - 79s 283ms/step - loss: 0.9542 - accuracy: 0.5433 - val_loss: 0.9507 - val_accuracy: 0.5379
# Epoch 17/30
# 280/280 [==============================] - 81s 291ms/step - loss: 0.9546 - accuracy: 0.5433 - val_loss: 0.9495 - val_accuracy: 0.5379
# Epoch 18/30
# 280/280 [==============================] - 77s 274ms/step - loss: 0.9542 - accuracy: 0.5433 - val_loss: 0.9500 - val_accuracy: 0.5379
# Epoch 19/30
# 280/280 [==============================] - 77s 276ms/step - loss: 0.9540 - accuracy: 0.5433 - val_loss: 0.9490 - val_accuracy: 0.5379
# Epoch 20/30
# 280/280 [==============================] - 83s 295ms/step - loss: 0.9540 - accuracy: 0.5433 - val_loss: 0.9492 - val_accuracy: 0.5379
# Epoch 21/30
# 280/280 [==============================] - 80s 287ms/step - loss: 0.9542 - accuracy: 0.5433 - val_loss: 0.9485 - val_accuracy: 0.5379
# Epoch 22/30
# 280/280 [==============================] - 83s 296ms/step - loss: 0.9539 - accuracy: 0.5433 - val_loss: 0.9486 - val_accuracy: 0.5379
# Epoch 23/30
# 280/280 [==============================] - 79s 284ms/step - loss: 0.9541 - accuracy: 0.5433 - val_loss: 0.9484 - val_accuracy: 0.5379
# Epoch 24/30
# 280/280 [==============================] - 78s 280ms/step - loss: 0.9539 - accuracy: 0.5433 - val_loss: 0.9492 - val_accuracy: 0.5379
# Epoch 25/30
# 280/280 [==============================] - 81s 290ms/step - loss: 0.9540 - accuracy: 0.5433 - val_loss: 0.9490 - val_accuracy: 0.5379
# Epoch 26/30
# 280/280 [==============================] - 79s 283ms/step - loss: 0.9540 - accuracy: 0.5433 - val_loss: 0.9485 - val_accuracy: 0.5379
# Epoch 27/30
# 280/280 [==============================] - 87s 311ms/step - loss: 0.9539 - accuracy: 0.5433 - val_loss: 0.9486 - val_accuracy: 0.5379
# Epoch 28/30
# 280/280 [==============================] - 79s 281ms/step - loss: 0.9539 - accuracy: 0.5433 - val_loss: 0.9485 - val_accuracy: 0.5379
# Epoch 29/30
# 280/280 [==============================] - 77s 276ms/step - loss: 0.9540 - accuracy: 0.5433 - val_loss: 0.9486 - val_accuracy: 0.5379
# Epoch 30/30
# 280/280 [==============================] - 83s 298ms/step - loss: 0.9539 - accuracy: 0.5433 - val_loss: 0.9483 - val_accuracy: 0.5379

# %%
pred_train = model.predict(train_x)
pred = model.predict(test_x)
pred = lb.inverse_transform(pred)

test['Class'] = pred
test.to_csv('submission.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-715f8dda1caf> in <cell line: 1>()
# ----> 1 pred_train = model.predict(train_x)
#       2 pred = model.predict(test_x)
#       3 pred = lb.inverse_transform(pred)
#       4
#       5 test['Class'] = pred
#
# NameError: name 'model' is not defined

# %%
i = random.choice(train.index)
img_name = train.ID[i]

img = imread(os.path.join(data_dir, 'train', img_name)).astype('float32')
plt.imshow(resize(img, (64, 64)))
print("Original : ", train.Class[i], 'Predicted:', lb.inverse_transform(pred_train[i]))
